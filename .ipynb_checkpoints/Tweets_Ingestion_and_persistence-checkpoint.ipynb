# %% [markdown]
# ## Use Case : tweets NLP
# This notebook addresses the use case of analyzing tweets related to **Inwi** and the **Moroccan telecommunications sector**.
#
# This is the **first notebook** that extracts tweets from twitter(X) and then stores them into a SQLite Database.
#
# The **second notebook** of this use case (**tweets-NLP.ipynb**) applies NLP on the tweets for sentiment analysis.
#
# ### Objectives:
# - Ingest fresh tweets their metadata using Selenium for web scraping.
# - Extract 10 tweets discussing Inwi and 10 tweets discussing the Moroccan telco sector.
# - Store the tweets and their metadata in a SQlite database.
# - Analyze the sentiment of tweets and score them from 0 (negative) to 1 (positive).
# - Investigate common topics in negative tweets.

# %% [markdown]
# ## Installing Dependencies
# Installing the necessary Python libraries to enable web scraping, database interaction and secrets management.

# %%
# !pip install selenium webdriver-manager pandas python-dotenv
# Out:
# Requirement already satisfied: selenium in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (4.26.1)
# Requirement already satisfied: webdriver-manager in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (4.0.2)
# Requirement already satisfied: pandas in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (2.2.3)
# Requirement already satisfied: python-dotenv in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (1.0.1)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from selenium) (1.26.20)
# Requirement already satisfied: trio~=0.17 in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from selenium) (0.27.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from selenium) (2024.8.30)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: requests in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from webdriver-manager) (2.32.3)
# Requirement already satisfied: packaging in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from webdriver-manager) (24.1)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from trio~=0.17->selenium) (24.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from trio~=0.17->selenium) (3.10)
# Requirement already satisfied: outcome in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from trio~=0.17->selenium) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from requests->webdriver-manager) (3.3.2)
# Requirement already satisfied: pycparser in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.22)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\zahra\desktop\jupyterprojects\venv\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: C:\Users\Zahra\Desktop\JupyterProjects\venv\Scripts\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Authentication Setup
# Loading login credentials to twitter(X) using environment variables from .env file.

# %%
from dotenv import load_dotenv
import os
# Load environment variables from the .env file
load_dotenv()

# Retrieve the value of MY_USER & MY_PASS from the environment
my_user = os.getenv("MY_USER")
my_pass = os.getenv("MY_PASS")

# %% [markdown]
# ## Part 1: Selenium WebScraping
# 1. Configure the Selenium WebDriver to access twitter login page.
# 2. search for INWI.
# 3. define functions to extract nbr_retweets, nbr_likes, author.
# 4. extract tweets and metadata
# 5. repeat steps: 5 for search : Maroc telecom

# %% [markdown]
# #### Configure the Selenium WebDriver to access twitter login page.

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By   #locate elements on a webpage
from selenium.webdriver.common.keys import Keys   #simulate keyboard keys on web browser
from time import sleep

from selenium.webdriver.chrome.service import Service  #for starting, stopping, and managing the ChromeDriver process, which is a separate executable program that allows Selenium to control Chrome.
from selenium.webdriver.chrome.options import Options  
from webdriver_manager.chrome import ChromeDriverManager

# %%
#download the correct ChromeDriver version for the scraping
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=Options())
#open Twitter login in the browser
driver.get("https://twitter.com/login")

# %%
# automatically input the username and click enter
user_id = driver.find_element(By.XPATH,"//input[@type='text']")
user_id.send_keys(my_user)
user_id.send_keys(Keys.ENTER)

# %%
# automatically input the password and click login
password = driver.find_element(By.XPATH,"//input[@type='password']")
password.send_keys(my_pass)
password.send_keys(Keys.ENTER)

# %% [markdown]
# #### search for INWI.

# %% [markdown]
# ##### function to search using a search_item

# %%
def perform_search(driver, search_term):
    """
    search operation using the search term.
    """
    search_box = driver.find_element(By.XPATH, "//input[@data-testid='SearchBox_Search_Input']")
    
    search_box.send_keys(Keys.CONTROL + "a")  # Select all text
    search_box.send_keys(Keys.DELETE)         # Delete selected text
    
    # Small delay to ensure clearing is complete
    sleep(0.5)
    
    # Enter new search term
    search_box.send_keys(search_term)
    search_box.send_keys(Keys.ENTER)
    
    # Small delay after search to ensure page responds
    sleep(1)

# %%
#searching for INWI
perform_search(driver, "INWI")

# %% [markdown]
# #### Define functions to extract metadata (nbr_likes, nbr_retweets, and author) from tweets.

# %%
def get_like_count(container):
    """
    Extract the number of likes of a tweet.
    """
    try:
        # using aria-label
        like_button = container.find_element(By.CSS_SELECTOR, "button[data-testid='like'][aria-label*='Likes']")
        likes_text = like_button.get_attribute('aria-label')
        # extract number from aria-label text: "6 Likes. Like"
        likes_number = likes_text.split()[0]
        return likes_number
    except Exception as e:
        print(f"Error getting like count: {str(e)}")
        return '0'

# %%
def get_retweet_count(driver):
    """
    Extract the number of retweets of a tweet.
    """
    # using aria-label
    retweet_button = driver.find_element(By.CSS_SELECTOR, "button[data-testid='retweet'][aria-label]")
    retweets_text = retweet_button.get_attribute('aria-label')
    # extract number from text like: "2 reposts. Repost"
    retweets_number = retweets_text.split()[0]
    return retweets_number

# %%
def get_author(container):
    """
    Extract the author of a tweet.
    """
    try:
        # Try to find the author (username) of the tweet
        author_element = container.find_element(By.CSS_SELECTOR, "div[data-testid='User-Name'] span")
        author_name = author_element.text
        return author_name
    except Exception as e:
        # Return None if there's an error (e.g., if the element is not found)
        print(f"Error extracting author: {str(e)}")
        return None

# %% [markdown]
# #### Extract tweets and metadata

# %%
all_tweets = []

while len(all_tweets) < 10: 
    # identify the containers that contain the tweets
    tweet_containers = driver.find_elements(By.CSS_SELECTOR, "article[data-testid='tweet']")
    
    for container in tweet_containers:
            tweet_data = {}
            
            # extract tweet text & date
            tweet_text = container.find_element(By.CSS_SELECTOR, '[data-testid="tweetText"]').text
            tweet_date = container.find_element(By.XPATH, ".//time").get_attribute('datetime')
            # extract likes, author, nbr_retweets using the functions
            nbr_likes = get_like_count(container)
            nbr_retweets = get_retweet_count(container)
            author = get_author(container)
            
            # skip if tweet exists
            if any(t['tweet_text'] == tweet_text for t in all_tweets):
                continue
                
                
            tweet_data['tweet_text'] = tweet_text
            tweet_data['tweet_date'] = tweet_date
            tweet_data['nbr_characters'] = len(tweet_text)
            tweet_data['nbr_likes'] = nbr_likes
            tweet_data['nbr_retweets'] = nbr_retweets
            tweet_data['author'] = author
            

            all_tweets.append(tweet_data)
            
            # if 10 tweets break the for loop
            if len(all_tweets) >= 10:
                break
            
    
    # Scroll to the bottom of the page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    sleep(3)

# %%
# Print results
for tweet in all_tweets:
    print("\nTweet:")
    print(f"Text: {tweet['tweet_text']}")
    print(f"Date: {tweet['tweet_date']}")
    print(f"Characters: {tweet['nbr_characters']}")
    print(f"Likes: {tweet['nbr_likes']}")
    print(f"Retweets: {tweet['nbr_retweets']}")
    print(f"Author: {tweet['author']}")
# Out:
# Tweet:
# Text:  Après la LNFP, c'est au la Botola Pro INWI qui aura très prochainement un compte officiel sur les réseaux sociaux.
# Date: 2024-11-09T22:07:54.000Z
# Characters: 115
# Likes: 8
# Retweets: 0
# Author: BotolaNews
#
# Tweet:
# Text: Official Botola Pro Inwi page will follow soon
# Date: 2024-11-09T21:38:11.000Z
# Characters: 46
# Likes: 30
# Retweets: 3
# Author: 𝗠𝗩𝗡_𝗘𝗡 | 𝗙𝗼𝗼𝘁𝗯𝗮𝗹𝗹 𝗡𝗲𝘄𝘀
#
# Tweet:
# Text: Je pense très sincèrement que l’absurdité est devenue organique chez
# @inwi
#  , après des dizaines d’appels et de réclamations depuis 3 semaines, une responsable du CRC me dit à nouveau “on essaie de vous joindre sans succès”
# Date: 2024-11-09T10:59:35.000Z
# Characters: 224
# Likes: 2
# Retweets: 1
# Author: from 04 with love
#
# Tweet:
# Text: Botola Inwi Pro is corrupted
# @fifacom_fr
# Date: 2024-11-09T21:50:20.000Z
# Characters: 41
# Likes: 2
# Retweets: 0
# Author: 🅜🅞🅝🅒🅔🅕
#
# Tweet:
# Text: Programme de la 5eme journée du championnat du Maroc de Futsal !!!!!
#
# Vu qu'il n'y a pas ce weekend de Botola Pro Inwi, Arryadia est dans l'obligation de nous retransmettre quelques matchs.
# Date: 2024-11-16T08:35:29.000Z
# Characters: 189
# Likes: 4
# Retweets: 0
# Author: Saad M
#
# Tweet:
# Text: Tous les buts de la 10ème journée de Botola Pro INWI :
# Date: 2024-11-10T19:25:57.000Z
# Characters: 54
# Likes: 6
# Retweets: 0
# Author: BotolaNews
#
# Tweet:
# Text: INWI
# MAROC
# Date: 2024-11-16T20:08:43.000Z
# Characters: 11
# Likes: 0
# Retweets: 0
# Author: Zaque bébé influenceur
#
# Tweet:
# Text: Un arbitre de la botola pro inwi
# Date: 2024-11-16T22:38:53.000Z
# Characters: 32
# Likes: 0
# Retweets: 0
# Author: Fc Recul
#
# Tweet:
# Text: A l'aeroport a casa quand la meuf d'inwi elle lui propose une carte sim gratuite #yousralkh #soukainatwosister
# Date: 2024-11-13T22:42:05.000Z
# Characters: 110
# Likes: 100
# Retweets: 13
# Author: am
#
# Tweet:
# Text: PUTANGINA NIYOWO INWI WENDY!!!/₱:₱8:₱:₱:
# Date: 2024-11-17T08:36:29.000Z
# Characters: 40
# Likes: 0
# Retweets: 0
# Author: bey ◡̈

# %% [markdown]
# #### Extract tweets about Maroc telecom

# %%
#searching for Maroc Telecom and clicking enter
perform_search(driver, "Maroc Telecom")

# %%
while len(all_tweets) < 20:  
    tweet_containers = driver.find_elements(By.CSS_SELECTOR, "article[data-testid='tweet']")
    
    for container in tweet_containers:
        try:
            tweet_data = {}
            
            # extract tweet text & date
            tweet_text = container.find_element(By.CSS_SELECTOR, '[data-testid="tweetText"]').text
            tweet_date = container.find_element(By.XPATH, ".//time").get_attribute('datetime')
            # extract likes, author, nbr_retweets using the functions
            nbr_likes = get_like_count(container)
            nbr_retweets = get_retweet_count(container)
            author = get_author(container)
            
            # skip if tweet exists
            if any(t['tweet_text'] == tweet_text for t in all_tweets):
                continue
                
                
            tweet_data['tweet_text'] = tweet_text
            tweet_data['tweet_date'] = tweet_date
            tweet_data['nbr_characters'] = len(tweet_text)
            tweet_data['nbr_likes'] = nbr_likes
            tweet_data['nbr_retweets'] = nbr_retweets
            tweet_data['author'] = author
            

            all_tweets.append(tweet_data)
            
            # if 10 tweets , break the for loop
            if len(all_tweets) >= 20:
                break
            
        except Exception as e:
            print(f"Error processing tweet: {str(e)}")
            continue
    
    # Scroll to the bottom of the page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    sleep(3)

# %%
# Print results
for tweet in all_tweets:
    print("\nTweet:")
    print(f"Text: {tweet['tweet_text']}")
    print(f"Date: {tweet['tweet_date']}")
    print(f"Characters: {tweet['nbr_characters']}")
    print(f"Likes: {tweet['nbr_likes']}")
    print(f"Retweets: {tweet['nbr_retweets']}")
    print(f"Author: {tweet['author']}")
# Out:
# Tweet:
# Text:  Après la LNFP, c'est au la Botola Pro INWI qui aura très prochainement un compte officiel sur les réseaux sociaux.
# Date: 2024-11-09T22:07:54.000Z
# Characters: 115
# Likes: 8
# Retweets: 0
# Author: BotolaNews
#
# Tweet:
# Text: Official Botola Pro Inwi page will follow soon
# Date: 2024-11-09T21:38:11.000Z
# Characters: 46
# Likes: 30
# Retweets: 3
# Author: 𝗠𝗩𝗡_𝗘𝗡 | 𝗙𝗼𝗼𝘁𝗯𝗮𝗹𝗹 𝗡𝗲𝘄𝘀
#
# Tweet:
# Text: Je pense très sincèrement que l’absurdité est devenue organique chez
# @inwi
#  , après des dizaines d’appels et de réclamations depuis 3 semaines, une responsable du CRC me dit à nouveau “on essaie de vous joindre sans succès”
# Date: 2024-11-09T10:59:35.000Z
# Characters: 224
# Likes: 2
# Retweets: 1
# Author: from 04 with love
#
# Tweet:
# Text: Botola Inwi Pro is corrupted
# @fifacom_fr
# Date: 2024-11-09T21:50:20.000Z
# Characters: 41
# Likes: 2
# Retweets: 0
# Author: 🅜🅞🅝🅒🅔🅕
#
# Tweet:
# Text: Programme de la 5eme journée du championnat du Maroc de Futsal !!!!!
#
# Vu qu'il n'y a pas ce weekend de Botola Pro Inwi, Arryadia est dans l'obligation de nous retransmettre quelques matchs.
# Date: 2024-11-16T08:35:29.000Z
# Characters: 189
# Likes: 4
# Retweets: 0
# Author: Saad M
#
# Tweet:
# Text: Tous les buts de la 10ème journée de Botola Pro INWI :
# Date: 2024-11-10T19:25:57.000Z
# Characters: 54
# Likes: 6
# Retweets: 0
# Author: BotolaNews
#
# Tweet:
# Text: INWI
# MAROC
# Date: 2024-11-16T20:08:43.000Z
# Characters: 11
# Likes: 0
# Retweets: 0
# Author: Zaque bébé influenceur
#
# Tweet:
# Text: Un arbitre de la botola pro inwi
# Date: 2024-11-16T22:38:53.000Z
# Characters: 32
# Likes: 0
# Retweets: 0
# Author: Fc Recul
#
# Tweet:
# Text: A l'aeroport a casa quand la meuf d'inwi elle lui propose une carte sim gratuite #yousralkh #soukainatwosister
# Date: 2024-11-13T22:42:05.000Z
# Characters: 110
# Likes: 100
# Retweets: 13
# Author: am
#
# Tweet:
# Text: PUTANGINA NIYOWO INWI WENDY!!!/₱:₱8:₱:₱:
# Date: 2024-11-17T08:36:29.000Z
# Characters: 40
# Likes: 0
# Retweets: 0
# Author: bey ◡̈
#
# Tweet:
# Text: Pour ceux qui ne realisent pas ce qui est en train de se passer.
#
# Apres les accords enormes avec les EAU , et maintenant ceux avec la France , le Maroc est en train de changer radicalement de dimension.
#
# Voilà un résume aussi bref que possible sur les investissements &
# Date: 2024-10-30T20:33:21.000Z
# Characters: 270
# Likes: 4930
# Retweets: 1355
# Author: Jaf
#
# Tweet:
# Text: Le Maroc  lance sa marque MoroccoTech pour confirmer la place du pays comme principal Hub technologique du continent africain.
# Date: 2022-01-17T20:50:59.000Z
# Characters: 126
# Likes: 480
# Retweets: 105
# Author: MM ۞
#
# Tweet:
# Text: | La stratégie "Maroc digital 2030" sera bientôt déployée.
#
# Cette stratégie vise à moderniser les services publics et renforcer l'économie numérique. La feuille de route inclue :
# - Le passage dans le top 50 mondial pour les services publics en ligne d'ici 2030
#
# - La création
# Date: 2023-10-31T10:37:48.000Z
# Characters: 276
# Likes: 480
# Retweets: 92
# Author: Morocco Intelligence
#
# Tweet:
# Text: Jusqu’au 30 novembre, profitez de -50% sur votre équipement fibre optique
# Plus d’information sur https://bit.ly/2OlqFW5
# Date: 2018-11-14T11:16:33.000Z
# Characters: 119
# Likes: 230
# Retweets: 18
# Author: Maroc Telecom
#
# Tweet:
# Text: Morocco Now shining on the glass tower of Maroc Telecom, that we thank on this occasion for their support.
#
# #MoroccoNow
# Date: 2021-10-13T22:02:08.000Z
# Characters: 119
# Likes: 325
# Retweets: 41
# Author: Morocco Now
#
# Tweet:
# Text: Maroc Télécom lyhrkjdbbkmlklb. Le pire service client de l'histoire de l'humanité. Des multiples appels depuis 3 semaines au 777 complètement inutiles. Bandes d'escrocs. Allah ou ma 1000 fois
# @OrangeMaroc
#  oulla ntouma. Crétins d'incompétents
# Date: 2022-04-26T16:24:40.000Z
# Characters: 244
# Likes: 192
# Retweets: 15
# Author: Amine Rahmouni
#
# Tweet:
# Text: — Maroc Télécom est en négociation avec le gouvernement Mauritanien pour fournir un câble internet qui traversera le Sahara Marocain sur 1600 km afin de renforcer la connexion internet en Mauritanie.
# Date: 2022-08-10T16:26:35.000Z
# Characters: 199
# Likes: 331
# Retweets: 44
# Author: MM ۞
#
# Tweet:
# Text:  | Avec l'aide de Maroc Telecom, Nouakchott réduit sa dépendance internet en se dotant d'un nouveau câble de fibre optique.
# Le câble suivrait un passage terrestre depuis le Maroc et passerait par Guerguerate avant d'arriver à Nouadhibou.
# Date: 2022-08-08T07:39:03.000Z
# Characters: 238
# Likes: 216
# Retweets: 34
# Author: Morocco Intelligence
#
# Tweet:
# Text: Comment ça Au Maroc  pour un forfait de 49dh soit 2940f tu as 11G d'internet 1h d'appel chaque vendredi on t'offre 10mn appel international
#
# Au senegal 2000F/ 4go
#
# #orangedoyna
# Date: 2024-05-17T23:01:24.000Z
# Characters: 178
# Likes: 299
# Retweets: 152
# Author: .ᗩ.ᗰ.ᗪ.
#
# Tweet:
# Text: Match Maroc-Guinée Equatoriale
# Envoyez MAROC au 3333 et gagnez des séjours à Agadir
# http://bit.ly/Maroc3333
# Date: 2015-10-19T19:30:18.000Z
# Characters: 109
# Likes: 215
# Retweets: 32
# Author: Maroc Telecom

# %% [markdown]
# #### -------------------------------------------------------------------------------

# %% [markdown]
# ## Part 2: Storing Tweets in SQLite

# %%
import sqlite3
from datetime import datetime

# SQLite database connection
conn = sqlite3.connect('tweetsDB.db')
cursor = conn.cursor()

# Create the table 
cursor.execute("""
CREATE TABLE IF NOT EXISTS tweets (
    id INTEGER PRIMARY KEY AUTOINCREMENT,  
    tweet_text TEXT NOT NULL,              
    tweet_date DATETIME,                   
    nbr_characters INTEGER,                
    nbr_retweets INTEGER,                  
    nbr_likes INTEGER,                     
    author TEXT
);
""")

# Prepare insert statement for tweets
insert_query = """
INSERT INTO tweets (tweet_text, tweet_date, nbr_characters, nbr_retweets, nbr_likes, author)
VALUES (?, ?, ?, ?, ?, ?);
"""

# Iterate over the tweets and insert them into the database
for tweet in all_tweets:
    tweet_text = tweet['tweet_text']
    tweet_date = datetime.strptime(tweet['tweet_date'], '%Y-%m-%dT%H:%M:%S.000Z')  # Convert string to datetime
    nbr_characters = int(tweet['nbr_characters'])
    nbr_retweets = int(tweet['nbr_retweets'])  # Convert to integer
    nbr_likes = int(tweet['nbr_likes'])  # Convert to integer
    author = tweet['author']

    cursor.execute(insert_query, (tweet_text, tweet_date, nbr_characters, nbr_retweets, nbr_likes, author))

# Commit and close the connection
conn.commit()
cursor.close()
conn.close()

print("Data inserted successfully!")
# Out:
# Data inserted successfully!

# %% [markdown]
# #### Verifying the tweets were ingested into the db

# %%
import sqlite3

# Connect to SQLite database
conn = sqlite3.connect('tweetsDB.db')
cursor = conn.cursor()

# Select all rows from the 'tweets' table
cursor.execute("SELECT * FROM tweets;")
rows = cursor.fetchall()

# Print each row
for row in rows:
    print(row)

# Close the cursor and connection
cursor.close()
conn.close()
# Out:
# (1, " Après la LNFP, c'est au la Botola Pro INWI qui aura très prochainement un compte officiel sur les réseaux sociaux.", '2024-11-09 22:07:54', 115, 0, 8, 'BotolaNews')
# (2, 'Official Botola Pro Inwi page will follow soon', '2024-11-09 21:38:11', 46, 3, 30, '𝗠𝗩𝗡_𝗘𝗡 | 𝗙𝗼𝗼𝘁𝗯𝗮𝗹𝗹 𝗡𝗲𝘄𝘀')
# (3, 'Je pense très sincèrement que l’absurdité est devenue organique chez \n@inwi\n , après des dizaines d’appels et de réclamations depuis 3 semaines, une responsable du CRC me dit à nouveau “on essaie de vous joindre sans succès”', '2024-11-09 10:59:35', 224, 1, 2, 'from 04 with love')
# (4, 'Botola Inwi Pro is corrupted \n@fifacom_fr', '2024-11-09 21:50:20', 41, 0, 2, '🅜🅞🅝🅒🅔🅕')
# (5, "Programme de la 5eme journée du championnat du Maroc de Futsal !!!!!\n\nVu qu'il n'y a pas ce weekend de Botola Pro Inwi, Arryadia est dans l'obligation de nous retransmettre quelques matchs.", '2024-11-16 08:35:29', 189, 0, 4, 'Saad M')
# (6, 'Tous les buts de la 10ème journée de Botola Pro INWI :', '2024-11-10 19:25:57', 54, 0, 6, 'BotolaNews')
# (7, 'INWI \nMAROC', '2024-11-16 20:08:43', 11, 0, 0, 'Zaque bébé influenceur')
# (8, 'Un arbitre de la botola pro inwi', '2024-11-16 22:38:53', 32, 0, 0, 'Fc Recul')
# (9, "A l'aeroport a casa quand la meuf d'inwi elle lui propose une carte sim gratuite #yousralkh #soukainatwosister", '2024-11-13 22:42:05', 110, 13, 100, 'am')
# (10, 'PUTANGINA NIYOWO INWI WENDY!!!/₱:₱8:₱:₱:', '2024-11-17 08:36:29', 40, 0, 0, 'bey ◡̈')
# (11, 'Pour ceux qui ne realisent pas ce qui est en train de se passer. \n\nApres les accords enormes avec les EAU , et maintenant ceux avec la France , le Maroc est en train de changer radicalement de dimension.\n\nVoilà un résume aussi bref que possible sur les investissements &', '2024-10-30 20:33:21', 270, 1355, 4930, 'Jaf')
# (12, 'Le Maroc  lance sa marque MoroccoTech pour confirmer la place du pays comme principal Hub technologique du continent africain.', '2022-01-17 20:50:59', 126, 105, 480, 'MM ۞')
# (13, '| La stratégie "Maroc digital 2030" sera bientôt déployée. \n\nCette stratégie vise à moderniser les services publics et renforcer l\'économie numérique. La feuille de route inclue :\n- Le passage dans le top 50 mondial pour les services publics en ligne d\'ici 2030\n\n- La création', '2023-10-31 10:37:48', 276, 92, 480, 'Morocco Intelligence')
# (14, 'Jusqu’au 30 novembre, profitez de -50% sur votre équipement fibre optique\nPlus d’information sur https://bit.ly/2OlqFW5', '2018-11-14 11:16:33', 119, 18, 230, 'Maroc Telecom')
# (15, 'Morocco Now shining on the glass tower of Maroc Telecom, that we thank on this occasion for their support.\n\n#MoroccoNow', '2021-10-13 22:02:08', 119, 41, 325, 'Morocco Now')
# (16, "Maroc Télécom lyhrkjdbbkmlklb. Le pire service client de l'histoire de l'humanité. Des multiples appels depuis 3 semaines au 777 complètement inutiles. Bandes d'escrocs. Allah ou ma 1000 fois \n@OrangeMaroc\n oulla ntouma. Crétins d'incompétents ", '2022-04-26 16:24:40', 244, 15, 192, 'Amine Rahmouni')
# (17, '— Maroc Télécom est en négociation avec le gouvernement Mauritanien pour fournir un câble internet qui traversera le Sahara Marocain sur 1600 km afin de\u2009renforcer la connexion internet en Mauritanie.', '2022-08-10 16:26:35', 199, 44, 331, 'MM ۞')
# (18, " | Avec l'aide de Maroc Telecom, Nouakchott réduit sa dépendance internet en se dotant d'un nouveau câble de fibre optique. \nLe câble suivrait un passage terrestre depuis le Maroc et passerait par Guerguerate avant d'arriver à Nouadhibou.", '2022-08-08 07:39:03', 238, 34, 216, 'Morocco Intelligence')
# (19, "Comment ça Au Maroc  pour un forfait de 49dh soit 2940f tu as 11G d'internet 1h d'appel chaque vendredi on t'offre 10mn appel international\n\nAu senegal 2000F/ 4go \n\n#orangedoyna ", '2024-05-17 23:01:24', 178, 152, 299, '.ᗩ.ᗰ.ᗪ.')
# (20, 'Match Maroc-Guinée Equatoriale \nEnvoyez MAROC au 3333 et gagnez des séjours à Agadir \nhttp://bit.ly/Maroc3333', '2015-10-19 19:30:18', 109, 32, 215, 'Maroc Telecom')

# %% [markdown]
# ## Conclusion
# This notebook includes the first two parts of the use case.
#
# I extracted data (using webscraping) from twitter to a SQLite DB.
#
# now, for the NLP part of the use case please check the notebook: **tweets-NLP.ipynb**
